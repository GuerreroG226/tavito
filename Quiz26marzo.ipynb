# %% [markdown]
# <a href="https://colab.research.google.com/github/GuerreroG226/tavito/blob/main/Quiz26marzo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile pedirnotas.py
def pedir_nombre():
  return input("Ingrese el nombre del estudiante: ")

def pedir_notas():
    n1 = float(input("La nota 1: "))
    n2 = float(input("La nota 2: "))
    n3 = float(input("La nota 3: "))
    n4 = float(input("La nota 4: "))
    return [n1, n2, n3, n4]
# Out:
# Overwriting pedirnotas.py

# %%
# %%writefile promedio.py
def dar_promedio(n1, n2, n3, n4):
  return (n1 + n2 + n3 + n4)/4
# Out:
# Overwriting promedio.py

# %%
import importlib
import pedirnotas
reload = importlib.reload(pedirnotas)
nombre = pedirnotas.pedir_nombre()
# Out:
# Ingrese el nombre del estudiante: Tavito

# %%
import importlib
reload = importlib.reload(pedirnotas)
notas = pedirnotas.pedir_notas()
# Out:
# La nota 1: 9.3
# La nota 2: 8.7
# La nota 3: 5.6
# La nota 4: 5.6

# %%
import promedio
importlib.reload(promedio)
prom = promedio.dar_promedio(*notas)

# %%
import statistics
import importlib
reload = importlib.reload(statistics)
def calcular_promedio(n1, n2, n3, n4):
  return (n1 + n2 + n3 + n4)/4


def mediana(n1, n2, n3, n4):
  return statistics.median([n1, n2, n3, n4])

def moda(n1, n2, n3, n4):
  return statistics.mode([n1, n2, n3, n4])

# %%
prom = promedio.dar_promedio(notas[0], notas[1], notas[2], notas[3])

print("Nombre:", nombre)
print("Notas:", notas)

if prom >= 3:
  print("Aprobó con un promedio de:", prom)
else:
  print("Reprobó con un promedio de:", prom)

print("Mediana:", mediana(notas[0], notas[1], notas[2], notas[3]))
print("Moda o tu calificación más repetida:", moda(notas[0], notas[1], notas[2], notas[3]))
# Out:
# Nombre: Tavito
# Notas: [9.3, 8.7, 5.6, 5.6]
# Aprobó con un promedio de: 7.300000000000001
# Mediana: 7.1499999999999995
# Moda o tu calificación más repetida: 5.6

# %%
print (f"El promedio del estudiante con las notas dadas es:, {prom}")
print (f"El estudiante pudo aprobar con una nota de: {fprom}")
print (f"La mediana de las notas es: {mediana(notas[0], notas[1], notas[2], notas[3])}")
print (f"La nota que mayor se repitió fue: {moda(notas[0], notas[1], notas[2], notas[3])}")
# Out:
# El promedio del estudiante con las notas dadas es:, 7.300000000000001
# El estudiante pudo aprobar con una nota de: 7.300000000000001
# La mediana de las notas es: 7.1499999999999995
# La nota que mayor se repitió fue: 5.6

# %% [markdown]
# Este código está creado con los módulos vistos en clase, un módulo para cada proceso, nombre, las notas, si aprobó o no, la mediana como su promedio, la mediana, y la moda.
